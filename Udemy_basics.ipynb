# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinr17/Py_relearn/blob/main/Udemy_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: print hello world

name=input("Whats your mame?")
print("hello again  "+name)
# Out:
# Whats your mame?zak
# hello again  zak
